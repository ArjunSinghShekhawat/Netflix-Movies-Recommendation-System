# %% [markdown]
# ## Fetch Hindi Movies From Wekipidia

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from requests.exceptions import Timeout, RequestException, ConnectionError
import numpy as np
from functools import lru_cache
from tmdbv3api import TMDb, Movie
from concurrent.futures import ThreadPoolExecutor, as_completed

tmdb = TMDb()
tmdb.api_key = '6d8bfe0dbef34d25e64f64cabec93e20'
tmdb_movie = Movie()

# Using LRU cache to store results of previously fetched movie genres
@lru_cache(maxsize=1000)
def fetch_movie_genres(movie_id):
    try:
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
        if response.status_code != 200:
            return np.nan
        
        data_json = response.json()
        if 'genres' in data_json and data_json['genres']:
            return " ".join([genre['name'] for genre in data_json['genres']])
        else:
            return np.nan
    except Exception as e:
        print(f"Error fetching genres for movie ID {movie_id}: {e}")
        return np.nan

def get_genres(x):
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.nan
        
        movie_id = result[0].id
        return fetch_movie_genres(movie_id)
    except Exception as e:
        print(f"Error fetching genres for {x}: {e}")
        return np.nan

# Setup retry strategy
retry_strategy = Retry(
    total=5,  # Total number of retries
    backoff_factor=2,  # Exponential backoff factor
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    method_whitelist=["HEAD", "GET", "OPTIONS"]  # Retry only on these methods
)

# Create an HTTP adapter with the retry strategy
adapter = HTTPAdapter(max_retries=retry_strategy)

# Create a session and mount the adapter
session = requests.Session()
session.mount("https://", adapter)
session.mount("http://", adapter)

def get(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if actor_list[0]:
            return actor_list[0].strip()
    return None

def get2(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if len(actor_list) >= 2:
            return actor_list[1].strip()
        else:
            return np.nan
    return np.nan

def get3(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if len(actor_list) >= 3:
            return actor_list[2].strip()
        else:
            return np.nan
    return np.nan

def fetch_html(url):
    try:
        response = session.get(url, timeout=20)
        response.raise_for_status()  # Raise an exception for HTTP errors
        return response.content
    except Timeout:
        print(f"Request timed out for URL {url}.")
        return None
    except ConnectionError as e:
        print(f"Connection error for URL {url}: {e}")
        return None
    except RequestException as e:
        print(f"Request error fetching data from URL {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error fetching data from URL {url}: {e}")
        return None

def create_df(url):
    # Fetch HTML content from the URL
    html_content = fetch_html(url)

    # Read HTML data using pandas if content is fetched successfully
    if html_content:
        try:
            # Reading multiple tables on the page
            tables = pd.read_html(html_content, header=0)
        
            # Extract specific tables
            df1 = tables[2]
            df2 = tables[3]
            df3 = tables[4]
            df4 = tables[5]
        
        except Exception as e:
            print(f"Error reading HTML content: {e}")
    else:
        print("Failed to fetch HTML content.")
    
    movies = pd.concat([df1, df2, df3, df4], axis=0).reset_index()

    movies = movies[['Title', 'Director', 'Cast']]
    movies['actor_1_name'] = movies['Cast'].apply(lambda x: get(x))
    movies['actor_2_name'] = movies['Cast'].apply(lambda x: get2(x))
    movies['actor_3_name'] = movies['Cast'].apply(lambda x: get3(x))
    movies = movies.rename(columns={'Title': 'movie_title', "Director": "director_name"})

    movies.drop('Cast', inplace=True, axis=1)
    movies['movie_title'] = movies['movie_title'].str.lower()

    movies['comb'] = movies['actor_1_name'] + " " + movies['actor_2_name'] + " " + movies['actor_3_name'] + " " + movies['director_name']
    
    # Parallelize genre fetching
    with ThreadPoolExecutor(max_workers=10) as executor:
        future_to_title = {executor.submit(get_genres, title): title for title in movies['movie_title']}
        for future in as_completed(future_to_title):
            title = future_to_title[future]
            try:
                genres = future.result()
                movies.loc[movies['movie_title'] == title, 'genres'] = genres
            except Exception as e:
                print(f"Error fetching genres for {title}: {e}")
    
    return movies
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_6844\1661761232.py:45: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(

# %%
data_2018_movies = create_df('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2018')
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_17288\1661761232.py:144: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Comedy Drama' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   movies.loc[movies['movie_title'] == title, 'genres'] = genres
# Error fetching genres for nan: quote_from_bytes() expected bytes

# %%
data_2018_movies.duplicated().sum()
# Out:
# 0

# %%
data_2018_movies.drop("comb",axis=1,inplace=True)

# %%
data_2018_movies
# Out:
#           movie_title    director_name          actor_1_name  \
# 0                1921     Vikram Bhatt           Zareen Khan
# 1         kaalakaandi     Akshat Verma         Saif Ali Khan
# 2           mukkabaaz   Anurag Kashyap    Vineet Kumar Singh
# 3          phir se...      Kunal Kohli       Jennifer Winget
# 4    my birthday song       Samir Soni           Sanjay Suri
# ..                ...              ...                   ...
# 99       rajma chawal      Leena Yadav          Rishi Kapoor
# 100         kedarnath  Abhishek Kapoor  Sushant Singh Rajput
# 101   ascharyachakit!     Samit Kakkad         Priyanka Bose
# 102              zero    Aanand L. Rai        Shah Rukh Khan
# 103            simmba     Rohit Shetty         Ranveer Singh
#
#           actor_2_name     actor_3_name                     genres
# 0         Karan Kundra    Tobby Hinston          History Drama War
# 1          Isha Talwar  Shenaz Treasury      Comedy Thriller Drama
# 2         Zoya Hussain      Ravi Kishan                      Drama
# 3          Kunal Kohli      Rajit Kapur               Comedy Drama
# 4          Nora Fatehi         Pitobash                   Thriller
# ..                 ...              ...                        ...
# 99      Anirudh Tanwar     Amyra Dastur        Comedy Drama Family
# 100      Sara Ali Khan              NaN                    Romance
# 101  Vaibhav Raj Gupta       Ankit Raaj             Thriller Drama
# 102       Katrina Kaif   Anushka Sharma            Animation Drama
# 103      Sara Ali Khan        Sonu Sood  Action Comedy Crime Drama
#
# [104 rows x 6 columns]

# %%
data_2018_movies.isnull().sum()
# Out:
# movie_title       1
# director_name     1
# actor_1_name      2
# actor_2_name      5
# actor_3_name     21
# genres            4
# dtype: int64

# %%
len(data_2018_movies)
# Out:
# 104

# %%
data_2018_movies.dropna(inplace=True)

# %%
data_2018_movies['comb'] = data_2018_movies['actor_1_name'] + " " + data_2018_movies['actor_2_name'] + " " + data_2018_movies['actor_3_name'] + " " + data_2018_movies['director_name']

# %%
data_2018_movies.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# comb             0
# dtype: int64

# %%
data_2018_movies
# Out:
#           movie_title   director_name        actor_1_name       actor_2_name  \
# 0                1921    Vikram Bhatt         Zareen Khan       Karan Kundra
# 1         kaalakaandi    Akshat Verma       Saif Ali Khan        Isha Talwar
# 2           mukkabaaz  Anurag Kashyap  Vineet Kumar Singh       Zoya Hussain
# 3          phir se...     Kunal Kohli     Jennifer Winget        Kunal Kohli
# 4    my birthday song      Samir Soni         Sanjay Suri        Nora Fatehi
# ..                ...             ...                 ...                ...
# 98                2.0       S Shankar          Rajnikanth        Amy Jackson
# 99       rajma chawal     Leena Yadav        Rishi Kapoor     Anirudh Tanwar
# 101   ascharyachakit!    Samit Kakkad       Priyanka Bose  Vaibhav Raj Gupta
# 102              zero   Aanand L. Rai      Shah Rukh Khan       Katrina Kaif
# 103            simmba    Rohit Shetty       Ranveer Singh      Sara Ali Khan
#
#         actor_3_name                          genres  \
# 0      Tobby Hinston               History Drama War
# 1    Shenaz Treasury           Comedy Thriller Drama
# 2        Ravi Kishan                           Drama
# 3        Rajit Kapur                    Comedy Drama
# 4           Pitobash                        Thriller
# ..               ...                             ...
# 98      Akshay Kumar  Action Science Fiction Fantasy
# 99      Amyra Dastur             Comedy Drama Family
# 101       Ankit Raaj                  Thriller Drama
# 102   Anushka Sharma                 Animation Drama
# 103        Sonu Sood       Action Comedy Crime Drama
#
#                                                   comb
# 0    Zareen Khan Karan Kundra Tobby Hinston Vikram ...
# 1    Saif Ali Khan Isha Talwar Shenaz Treasury Aksh...
# 2    Vineet Kumar Singh Zoya Hussain Ravi Kishan An...
# 3    Jennifer Winget Kunal Kohli Rajit Kapur Kunal ...
# 4          Sanjay Suri Nora Fatehi Pitobash Samir Soni
# ..                                                 ...
# 98       Rajnikanth Amy Jackson Akshay Kumar S Shankar
# 99   Rishi Kapoor Anirudh Tanwar Amyra Dastur Leena...
# 101  Priyanka Bose Vaibhav Raj Gupta Ankit Raaj Sam...
# 102  Shah Rukh Khan Katrina Kaif Anushka Sharma Aan...
# 103  Ranveer Singh Sara Ali Khan Sonu Sood Rohit Sh...
#
# [80 rows x 7 columns]

# %%
data_2018_movies.to_csv("data_2018_movies.csv",index=False)

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from requests.exceptions import Timeout, RequestException, ConnectionError
import numpy as np
from functools import lru_cache
from tmdbv3api import TMDb, Movie
from concurrent.futures import ThreadPoolExecutor, as_completed

tmdb = TMDb()
tmdb.api_key = '6d8bfe0dbef34d25e64f64cabec93e20'
tmdb_movie = Movie()

# Using LRU cache to store results of previously fetched movie genres
@lru_cache(maxsize=1000)
def fetch_movie_genres(movie_id):
    try:
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
        if response.status_code != 200:
            return np.nan
        
        data_json = response.json()
        if 'genres' in data_json and data_json['genres']:
            return " ".join([genre['name'] for genre in data_json['genres']])
        else:
            return np.nan
    except Exception as e:
        print(f"Error fetching genres for movie ID {movie_id}: {e}")
        return np.nan

def get_genres(x):
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.nan
        
        movie_id = result[0].id
        return fetch_movie_genres(movie_id)
    except Exception as e:
        print(f"Error fetching genres for {x}: {e}")
        return np.nan

# Setup retry strategy
retry_strategy = Retry(
    total=5,  # Total number of retries
    backoff_factor=2,  # Exponential backoff factor
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    method_whitelist=["HEAD", "GET", "OPTIONS"]  # Retry only on these methods
)

# Create an HTTP adapter with the retry strategy
adapter = HTTPAdapter(max_retries=retry_strategy)

# Create a session and mount the adapter
session = requests.Session()
session.mount("https://", adapter)
session.mount("http://", adapter)

def get(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if actor_list[0]:
            return actor_list[0].strip()
    return None

def get2(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if len(actor_list) >= 2:
            return actor_list[1].strip()
        else:
            return np.nan
    return np.nan

def get3(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if len(actor_list) >= 3:
            return actor_list[2].strip()
        else:
            return np.nan
    return np.nan

def fetch_html(url):
    try:
        response = session.get(url, timeout=20)
        response.raise_for_status()  # Raise an exception for HTTP errors
        return response.content
    except Timeout:
        print(f"Request timed out for URL {url}.")
        return None
    except ConnectionError as e:
        print(f"Connection error for URL {url}: {e}")
        return None
    except RequestException as e:
        print(f"Request error fetching data from URL {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error fetching data from URL {url}: {e}")
        return None

def create_df(url):
    # Fetch HTML content from the URL
    html_content = fetch_html(url)

    # Read HTML data using pandas if content is fetched successfully
    if html_content:
        try:
            # Reading multiple tables on the page
            tables = pd.read_html(html_content, header=0)
        
            # Extract specific tables

            df1 = tables[3]
            df2 = tables[4]
            df3 = tables[5]
            df4 = tables[6]
        
        except Exception as e:
            print(f"Error reading HTML content: {e}")
    else:
        print("Failed to fetch HTML content.")
    
    return df1,df2,df3,df4
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_6844\2662029239.py:45: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(

# %%
d1,d2,d3,d4 = create_df('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2020')

# %%
data_2020_movies = pd.concat([d1,d2,d3,d4]).reset_index()

# %%
data_2020_movies = data_2020_movies[['Title','Director','Cast']]

# %%
data_2020_movies
# Out:
#                  Title                                           Director  \
# 0              Bamfaad                                     Ranjan Chandel
# 1                Ateet                                      Tanuj Bhramar
# 2   Mrs. Serial Killer                                     Shirish Kunder
# 3        Court Martial                                 Sourabh Srivastava
# 4    What Are the Odds                                    Megha Ramaswamy
# ..                 ...                                                ...
# 61            Unpaused  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...
# 62            AK vs AK                               Vikramaditya Motwane
# 63        Coolie No. 1                                       David Dhawan
# 64            Shakeela                                   Indrajit Lankesh
# 65                 NaN                                                NaN
#
#                                                  Cast
# 0               Aditya RawalShalini PandeyVijay Varma
# 1               PriyamaniSanjay SuriRajeev Khandelwal
# 2   Jacqueline FernandezManoj BajpayeeMohit RainaZ...
# 3       Rajeev KhandelwalSaksham DaymaSwapnil Kotiwar
# 4        Yashaswini DayamaKaranvir MalhotraAbhay Deol
# ..                                                ...
# 61  Gulshan DevaiahSumeet VyasSaiyami KherRicha Ch...
# 62                          Anil KapoorAnurag Kashyap
# 63                          Varun DhawanSara Ali Khan
# 64           Richa ChaddaPankaj TripathiRajeev Pillai
# 65                                                NaN
#
# [66 rows x 3 columns]

# %%
data_2020_movies['Cast'] = data_2020_movies['Cast'].fillna('')

import re

# Apply the split function
data_2020_movies['Cast'] = data_2020_movies['Cast'].apply(
    lambda x: re.split(r'(?<=[a-z])(?=[A-Z])', x)
)

# %%
data_2020_movies
# Out:
#                  Title                                           Director  \
# 0              Bamfaad                                     Ranjan Chandel
# 1                Ateet                                      Tanuj Bhramar
# 2   Mrs. Serial Killer                                     Shirish Kunder
# 3        Court Martial                                 Sourabh Srivastava
# 4    What Are the Odds                                    Megha Ramaswamy
# ..                 ...                                                ...
# 61            Unpaused  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...
# 62            AK vs AK                               Vikramaditya Motwane
# 63        Coolie No. 1                                       David Dhawan
# 64            Shakeela                                   Indrajit Lankesh
# 65                 NaN                                                NaN
#
#                                                  Cast
# 0         [Aditya Rawal, Shalini Pandey, Vijay Varma]
# 1         [Priyamani, Sanjay Suri, Rajeev Khandelwal]
# 2   [Jacqueline Fernandez, Manoj Bajpayee, Mohit R...
# 3   [Rajeev Khandelwal, Saksham Dayma, Swapnil Kot...
# 4   [Yashaswini Dayama, Karanvir Malhotra, Abhay D...
# ..                                                ...
# 61  [Gulshan Devaiah, Sumeet Vyas, Saiyami Kher, R...
# 62                      [Anil Kapoor, Anurag Kashyap]
# 63                      [Varun Dhawan, Sara Ali Khan]
# 64     [Richa Chadda, Pankaj Tripathi, Rajeev Pillai]
# 65                                                 []
#
# [66 rows x 3 columns]

# %%
data_2020_movies['Cast'][2]
# Out:
# ['Jacqueline Fernandez', 'Manoj Bajpayee', 'Mohit Raina', 'Zayn Marie']

# %%
def get_actor1(text):

    actor_list = []

    for i in text:

        if i!="" and i != np.nan:
            actor_list.append(i)
    if len(actor_list)>=1:
        return actor_list[0]
    else:
        return np.nan

# %%
data_2020_movies['actor_1_name'] = data_2020_movies['Cast'].apply(lambda x:get_actor1(x))

# %%
def get_actor2(text):

    actor_list = []

    for i in text:

        if i!="" and i != np.nan:
            actor_list.append(i)
    if len(actor_list)>=2:
        return actor_list[1]
    else:
        return np.nan

# %%
data_2020_movies['actor_2_name'] = data_2020_movies['Cast'].apply(lambda x:get_actor2(x))

# %%
def get_actor3(text):

    actor_list = []

    for i in text:

        if i!="" and i != np.nan:
            actor_list.append(i)
    if len(actor_list)>=3:
        return actor_list[2]
    else:
        return np.nan

# %%
data_2020_movies['actor_3_name'] = data_2020_movies['Cast'].apply(lambda x:get_actor3(x))

# %%
data_2020_movies
# Out:
#                  Title                                           Director  \
# 0              Bamfaad                                     Ranjan Chandel
# 1                Ateet                                      Tanuj Bhramar
# 2   Mrs. Serial Killer                                     Shirish Kunder
# 3        Court Martial                                 Sourabh Srivastava
# 4    What Are the Odds                                    Megha Ramaswamy
# ..                 ...                                                ...
# 61            Unpaused  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...
# 62            AK vs AK                               Vikramaditya Motwane
# 63        Coolie No. 1                                       David Dhawan
# 64            Shakeela                                   Indrajit Lankesh
# 65                 NaN                                                NaN
#
#                                                  Cast          actor_1_name  \
# 0         [Aditya Rawal, Shalini Pandey, Vijay Varma]          Aditya Rawal
# 1         [Priyamani, Sanjay Suri, Rajeev Khandelwal]             Priyamani
# 2   [Jacqueline Fernandez, Manoj Bajpayee, Mohit R...  Jacqueline Fernandez
# 3   [Rajeev Khandelwal, Saksham Dayma, Swapnil Kot...     Rajeev Khandelwal
# 4   [Yashaswini Dayama, Karanvir Malhotra, Abhay D...     Yashaswini Dayama
# ..                                                ...                   ...
# 61  [Gulshan Devaiah, Sumeet Vyas, Saiyami Kher, R...       Gulshan Devaiah
# 62                      [Anil Kapoor, Anurag Kashyap]           Anil Kapoor
# 63                      [Varun Dhawan, Sara Ali Khan]          Varun Dhawan
# 64     [Richa Chadda, Pankaj Tripathi, Rajeev Pillai]          Richa Chadda
# 65                                                 []                   NaN
#
#          actor_2_name       actor_3_name
# 0      Shalini Pandey        Vijay Varma
# 1         Sanjay Suri  Rajeev Khandelwal
# 2      Manoj Bajpayee        Mohit Raina
# 3       Saksham Dayma    Swapnil Kotiwar
# 4   Karanvir Malhotra         Abhay Deol
# ..                ...                ...
# 61        Sumeet Vyas       Saiyami Kher
# 62     Anurag Kashyap                NaN
# 63      Sara Ali Khan                NaN
# 64    Pankaj Tripathi      Rajeev Pillai
# 65                NaN                NaN
#
# [66 rows x 6 columns]

# %%
data_2020_movies.drop('Cast',axis=1,inplace=True)

# %%
data_2020_movies
# Out:
#                  Title                                           Director  \
# 0              Bamfaad                                     Ranjan Chandel
# 1                Ateet                                      Tanuj Bhramar
# 2   Mrs. Serial Killer                                     Shirish Kunder
# 3        Court Martial                                 Sourabh Srivastava
# 4    What Are the Odds                                    Megha Ramaswamy
# ..                 ...                                                ...
# 61            Unpaused  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...
# 62            AK vs AK                               Vikramaditya Motwane
# 63        Coolie No. 1                                       David Dhawan
# 64            Shakeela                                   Indrajit Lankesh
# 65                 NaN                                                NaN
#
#             actor_1_name       actor_2_name       actor_3_name
# 0           Aditya Rawal     Shalini Pandey        Vijay Varma
# 1              Priyamani        Sanjay Suri  Rajeev Khandelwal
# 2   Jacqueline Fernandez     Manoj Bajpayee        Mohit Raina
# 3      Rajeev Khandelwal      Saksham Dayma    Swapnil Kotiwar
# 4      Yashaswini Dayama  Karanvir Malhotra         Abhay Deol
# ..                   ...                ...                ...
# 61       Gulshan Devaiah        Sumeet Vyas       Saiyami Kher
# 62           Anil Kapoor     Anurag Kashyap                NaN
# 63          Varun Dhawan      Sara Ali Khan                NaN
# 64          Richa Chadda    Pankaj Tripathi      Rajeev Pillai
# 65                   NaN                NaN                NaN
#
# [66 rows x 5 columns]

# %%
data_2020_movies['Title'] = data_2020_movies['Title'].str.lower()

# %%
data_2020_movies = data_2020_movies.rename(columns={'Title':'movie_title','Director':'director_name'})

# %%
data_2020_movies
# Out:
#            movie_title                                      director_name  \
# 0              bamfaad                                     Ranjan Chandel
# 1                ateet                                      Tanuj Bhramar
# 2   mrs. serial killer                                     Shirish Kunder
# 3        court martial                                 Sourabh Srivastava
# 4    what are the odds                                    Megha Ramaswamy
# ..                 ...                                                ...
# 61            unpaused  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...
# 62            ak vs ak                               Vikramaditya Motwane
# 63        coolie no. 1                                       David Dhawan
# 64            shakeela                                   Indrajit Lankesh
# 65                 NaN                                                NaN
#
#             actor_1_name       actor_2_name       actor_3_name
# 0           Aditya Rawal     Shalini Pandey        Vijay Varma
# 1              Priyamani        Sanjay Suri  Rajeev Khandelwal
# 2   Jacqueline Fernandez     Manoj Bajpayee        Mohit Raina
# 3      Rajeev Khandelwal      Saksham Dayma    Swapnil Kotiwar
# 4      Yashaswini Dayama  Karanvir Malhotra         Abhay Deol
# ..                   ...                ...                ...
# 61       Gulshan Devaiah        Sumeet Vyas       Saiyami Kher
# 62           Anil Kapoor     Anurag Kashyap                NaN
# 63          Varun Dhawan      Sara Ali Khan                NaN
# 64          Richa Chadda    Pankaj Tripathi      Rajeev Pillai
# 65                   NaN                NaN                NaN
#
# [66 rows x 5 columns]

# %%
data_2020_movies['genres'] = data_2020_movies['movie_title'].apply(lambda x:get_genres(x))
# Out:
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for bahut hua samman: attribute name must be string, not 'int'
# Error fetching genres for nan: quote_from_bytes() expected bytes

# %%
data_2020_movies
# Out:
#            movie_title                                      director_name  \
# 0              bamfaad                                     Ranjan Chandel
# 1                ateet                                      Tanuj Bhramar
# 2   mrs. serial killer                                     Shirish Kunder
# 3        court martial                                 Sourabh Srivastava
# 4    what are the odds                                    Megha Ramaswamy
# ..                 ...                                                ...
# 61            unpaused  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...
# 62            ak vs ak                               Vikramaditya Motwane
# 63        coolie no. 1                                       David Dhawan
# 64            shakeela                                   Indrajit Lankesh
# 65                 NaN                                                NaN
#
#             actor_1_name       actor_2_name       actor_3_name  \
# 0           Aditya Rawal     Shalini Pandey        Vijay Varma
# 1              Priyamani        Sanjay Suri  Rajeev Khandelwal
# 2   Jacqueline Fernandez     Manoj Bajpayee        Mohit Raina
# 3      Rajeev Khandelwal      Saksham Dayma    Swapnil Kotiwar
# 4      Yashaswini Dayama  Karanvir Malhotra         Abhay Deol
# ..                   ...                ...                ...
# 61       Gulshan Devaiah        Sumeet Vyas       Saiyami Kher
# 62           Anil Kapoor     Anurag Kashyap                NaN
# 63          Varun Dhawan      Sara Ali Khan                NaN
# 64          Richa Chadda    Pankaj Tripathi      Rajeev Pillai
# 65                   NaN                NaN                NaN
#
#                        genres
# 0               Romance Drama
# 1              Thriller Drama
# 2                    Thriller
# 3                       Drama
# 4                Drama Family
# ..                        ...
# 61               Comedy Drama
# 62  Comedy Action Drama Crime
# 63               Comedy Drama
# 64              Drama Romance
# 65                        NaN
#
# [66 rows x 6 columns]

# %%
data_2020_movies.isnull().sum()
# Out:
# movie_title       2
# director_name     2
# actor_1_name      2
# actor_2_name      2
# actor_3_name     15
# genres            7
# dtype: int64

# %%
len(data_2020_movies)
# Out:
# 66

# %%
data_2020_movies.duplicated().sum()
# Out:
# 1

# %%
data_2020_movies.drop_duplicates(subset='movie_title',inplace=True)

# %%
data_2020_movies.dropna(inplace=True)

# %%
len(data_2020_movies)
# Out:
# 46

# %%
data_2020_movies.duplicated().sum()
# Out:
# 0

# %%
data_2020_movies.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data_2020_movies.to_csv('data_2020_movies.csv',index=False)

# %%
data_2020_movies
# Out:
#                             movie_title  \
# 0                               bamfaad
# 1                                 ateet
# 2                    mrs. serial killer
# 3                         court martial
# 4                     what are the odds
# 5                             ghoomketu
# 6                                chippa
# 7                    chintu ka birthday
# 8                                choked
# 9                                 axone
# 10                        gulabo sitabo
# 11                               kadakh
# 13                              bulbbul
# 14                              bhonsle
# 15                               unlock
# 17                          dil bechara
# 18                                yaara
# 19                      shakuntala devi
# 20                             lootcase
# 21                       raat akeli hai
# 23       gunjan saxena: the kargil girl
# 24                         khuda haafiz
# 25                       captain vidyut
# 26                         class of '83
# 27                           mee raqsam
# 28                              sadak 2
# 29                    ram singh charlie
# 30                        atkan chatkan
# 32  dolly kitty aur woh chamakte sitare
# 33                  london confidential
# 36                         khaali peeli
# 37                          serious men
# 43                                taish
# 44                          kaali khuhi
# 45                       pepper chicken
# 47                                 ludo
# 51                suraj pe mangal bhari
# 52                  anwar ka ajab kissa
# 53                              darbaan
# 54                            durgamati
# 56                          nirvana inn
# 57                              torbaaz
# 58                       eeb allay ooo!
# 59                              sayonee
# 61                             unpaused
# 64                             shakeela
#
#                                         director_name          actor_1_name  \
# 0                                      Ranjan Chandel          Aditya Rawal
# 1                                       Tanuj Bhramar             Priyamani
# 2                                      Shirish Kunder  Jacqueline Fernandez
# 3                                  Sourabh Srivastava     Rajeev Khandelwal
# 4                                     Megha Ramaswamy     Yashaswini Dayama
# 5                               Pushpendra Nath Misra   Nawazuddin Siddiqui
# 6                                       Safdar Rehman           Sunny Pawar
# 7                       Devanshu KumarSatyanshu Singh          Vinay Pathak
# 8                                      Anurag Kashyap          Saiyami Kher
# 9                                 Nicholas Kharkongor       Dolly Ahluwalia
# 10                                     Shoojit Sircar        Farrukh Jaffar
# 11                                       Rajat Kapoor        Kalki Koechlin
# 13                                        Anvita Dutt          Tripti Dimri
# 14                                  Devashish Makhija        Manoj Bajpayee
# 15                                     Debatma Mandal         Kushal Tandon
# 17                                     Mukesh Chhabra  Sushant Singh Rajput
# 18                                   Tigmanshu Dhulia        Vidyut Jammwal
# 19                                          Anu Menon           Vidya Balan
# 20                                    Rajesh Krishnan           Kunal Khemu
# 21                                       Honey Trehan   Nawazuddin Siddiqui
# 23                                      Sharan Sharma         Janhvi Kapoor
# 24                                        Faruk Kabir        Vidyut Jammwal
# 25                                      Atish Tipathi             Namit Das
# 26                                     Atul Sabharwal            Bobby Deol
# 27                                          Baba Azmi      Naseeruddin Shah
# 28                                       Mahesh Bhatt           Sanjay Dutt
# 29                                       Nitin Kakkar          Kumud Mishra
# 30                                          Shiv Hare      Sachin Chaudhary
# 32                              Alankrita Shrivastava    Konkona Sen Sharma
# 33                                       Kanwal Sethi             Mouni Roy
# 36                                       Maqbool Khan        Ishaan Khatter
# 37                                      Sudhir Mishra   Nawazuddin Siddiqui
# 43                                      Bejoy Nambiar         Pulkit Samrat
# 44                                    Terrie Samundra          Shabana Azmi
# 45                                      Ratan Sil Ram      Dipannita Sharma
# 47                                        Anurag Basu     Abhishek Bachchan
# 51                                    Abhishek Sharma        Manoj Bajpayee
# 52                                 Buddhadeb Dasgupta   Nawazuddin Siddiqui
# 53                                     Bipin Nadkarni         Sharib Hashmi
# 54                                           G. Ashok        Bhumi Pednekar
# 56                                      Vijay Jayapal          Adil Hussain
# 57                                       Girish Malik           Sanjay Dutt
# 58                                       Prateek Vats     Shardul Bharadwaj
# 59                     Nitin Kumar GuptaAbhay Singhal         Tanmay Ssingh
# 61  Raj & D.KNitya MehraNikkhil AdvaniTannishtha C...       Gulshan Devaiah
# 64                                   Indrajit Lankesh          Richa Chadda
#
#            actor_2_name               actor_3_name  \
# 0        Shalini Pandey                Vijay Varma
# 1           Sanjay Suri          Rajeev Khandelwal
# 2        Manoj Bajpayee                Mohit Raina
# 3         Saksham Dayma            Swapnil Kotiwar
# 4     Karanvir Malhotra                 Abhay Deol
# 5         Ragini Khanna               Richa Chadha
# 6   Joyraj Bhattacharya              Sumeet Thakur
# 7       Tillotama Shome                Nate Scholz
# 8         Roshan Mathew             Amruta Subhash
# 9          Sayani Gupta               Tenzin Dalha
# 10     Amitabh Bachchan         Ayushmann Khurrana
# 11        Ranvir Shorey                Shruti Seth
# 13       Avinash Tiwary                 Rahul Bose
# 14      Santosh Juvekar  Ipshita Chakraborty Singh
# 15            Hina Khan              Rishabh Sinha
# 17       Sanjana Sanghi              Saif Ali Khan
# 18        Shruti Haasan                  Amit Sadh
# 19      Jisshu Sengupta             Sanya Malhotra
# 20         Rasika Dugal                 Vijay Raaz
# 21         Radhika Apte            Shweta Tripathi
# 23      Pankaj Tripathi                 Angad Bedi
# 24    Shivaleeka Oberoi                Annu Kapoor
# 25         Suresh Menon                Trisha Kale
# 26    Bhupendra Jadawat             Hitesh Bhojraj
# 27        Danish Husain               Aditi Subedi
# 28          Pooja Bhatt                 Alia Bhatt
# 29          Divya Dutta             Akarsh Khurana
# 30            Yash Rane              Tamanna Dipak
# 32       Bhumi Pednekar              Amol Parashar
# 33          Purab Kohli            Kulraj Randhawa
# 36        Ananya Panday            Jaideep Ahlawat
# 37         Aakshath Das         Shweta Basu Prasad
# 43      Kriti Kharbanda                  Jim Sarbh
# 44     Satyadeep Mishra                 Riva Arora
# 45          Boloram Das              Baharul Islam
# 47        Rajkummar Rao           Aditya Roy Kapur
# 51       Diljit Dosanjh         Fatima Sana Shaikh
# 52    Ananya Chatterjee            Pankaj Tripathi
# 53        Sharad Kelkar                Flora Saini
# 54         Arshad Warsi            Jisshu Sengupta
# 56    Rajshri Deshpande             Sandhya Mridul
# 57        Nargis Fakhri                  Rahul Dev
# 58        Mahender Nath                Nutan Sinha
# 59        Musskan Sethi                  Rahul Roy
# 61          Sumeet Vyas               Saiyami Kher
# 64      Pankaj Tripathi              Rajeev Pillai
#
#                             genres
# 0                    Romance Drama
# 1                   Thriller Drama
# 2                         Thriller
# 3                            Drama
# 4                     Drama Family
# 5                     Comedy Drama
# 6                            Drama
# 7                            Drama
# 8             Drama Crime Thriller
# 9                     Drama Comedy
# 10                    Drama Comedy
# 11     Thriller Comedy Crime Drama
# 13                  Horror Fantasy
# 14                           Drama
# 15                 Horror Thriller
# 17                   Drama Romance
# 18             Family Drama Action
# 19             Drama Family Comedy
# 20                          Comedy
# 21          Crime Mystery Thriller
# 23                    Action Drama
# 24                 Action Thriller
# 25         Action Comedy Animation
# 26              Action Crime Drama
# 27                           Drama
# 28            Romance Drama Action
# 29                    Drama Comedy
# 30                     Drama Music
# 32                    Comedy Drama
# 33            Thriller Crime Drama
# 36  Romance Action Comedy Thriller
# 37                    Drama Comedy
# 43                     Documentary
# 44           Horror Drama Thriller
# 45                        Thriller
# 47                          Horror
# 51                    Comedy Drama
# 52                    Comedy Drama
# 53                           Drama
# 54                 Horror Thriller
# 56          Mystery Drama Thriller
# 57                           Drama
# 58                    Comedy Drama
# 59                  Action Romance
# 61                    Comedy Drama
# 64                   Drama Romance

# %%
d1,d2,d3,d4 = create_df('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2021')

# %%
data_2021_movies = pd.concat([d1,d2,d3,d4]).reset_index()

# %%
data_2021_movies = data_2021_movies[['Title','Director','Cast']]

# %%
data_2021_movies
# Out:
#                           Title                 Director  \
# 0                        Flight              Suraj Joshi
# 1                  Koi Jaane Na               Amin Hajee
# 2                  The Big Bull            Kookie Gulati
# 3                 Hello Charlie          Pankaj Saraswat
# 4                   99 Songs[b]  Vishwesh Krishnamoorthy
# ..                          ...                      ...
# 66                           83               Kabir Khan
# 67                   Atrangi Re            Aanand L. Rai
# 68  Murder at Teesri Manzil 302        Navneet Baj Saini
# 69                 Waah Zindagi           Dinesh S Yadav
# 70                          NaN                      NaN
#
#                                                  Cast
# 0   Mohit ChaddaPavan MalhotraZakir HussainVivek V...
# 1                            Kunal KapoorAmyra Dastur
# 2   Abhishek BachchanIleana D'CruzSohum ShahNikita...
# 3   Aadar JainJackie ShroffElnaaz NorouziShlokka P...
# 4   Ehan BhatEdilsy VargasTenzin DalhaAditya SealL...
# ..                                                ...
# 66  Ranveer SinghDeepika PadukoneTahir Raj BhasinJ...
# 67                   DhanushSara Ali KhanAkshay Kumar
# 68       Irrfan KhanRanvir ShoreyDeepal ShawLucky Ali
# 69  Naveen KasturiaPlabita BorthakurVijay RaazSanj...
# 70                                                NaN
#
# [71 rows x 3 columns]

# %%
data_2021_movies['Cast'] = data_2021_movies['Cast'].fillna('')

import re

# Apply the split function
data_2021_movies['Cast'] = data_2021_movies['Cast'].apply(
    lambda x: re.split(r'(?<=[a-z])(?=[A-Z])', x)
)

# %%
data_2021_movies
# Out:
#                           Title                 Director  \
# 0                        Flight              Suraj Joshi
# 1                  Koi Jaane Na               Amin Hajee
# 2                  The Big Bull            Kookie Gulati
# 3                 Hello Charlie          Pankaj Saraswat
# 4                   99 Songs[b]  Vishwesh Krishnamoorthy
# ..                          ...                      ...
# 66                           83               Kabir Khan
# 67                   Atrangi Re            Aanand L. Rai
# 68  Murder at Teesri Manzil 302        Navneet Baj Saini
# 69                 Waah Zindagi           Dinesh S Yadav
# 70                          NaN                      NaN
#
#                                                  Cast
# 0   [Mohit Chadda, Pavan Malhotra, Zakir Hussain, ...
# 1                        [Kunal Kapoor, Amyra Dastur]
# 2   [Abhishek Bachchan, Ileana D'Cruz, Sohum Shah,...
# 3   [Aadar Jain, Jackie Shroff, Elnaaz Norouzi, Sh...
# 4   [Ehan Bhat, Edilsy Vargas, Tenzin Dalha, Adity...
# ..                                                ...
# 66  [Ranveer Singh, Deepika Padukone, Tahir Raj Bh...
# 67             [Dhanush, Sara Ali Khan, Akshay Kumar]
# 68  [Irrfan Khan, Ranvir Shorey, Deepal Shaw, Luck...
# 69  [Naveen Kasturia, Plabita Borthakur, Vijay Raa...
# 70                                                 []
#
# [71 rows x 3 columns]

# %%
data_2021_movies['actor_1_name'] = data_2021_movies['Cast'].apply(lambda x:get_actor1(x))
data_2021_movies['actor_2_name'] = data_2021_movies['Cast'].apply(lambda x:get_actor2(x))
data_2021_movies['actor_3_name'] = data_2021_movies['Cast'].apply(lambda x:get_actor3(x))

# %%
data_2021_movies
# Out:
#                           Title                 Director  \
# 0                        Flight              Suraj Joshi
# 1                  Koi Jaane Na               Amin Hajee
# 2                  The Big Bull            Kookie Gulati
# 3                 Hello Charlie          Pankaj Saraswat
# 4                   99 Songs[b]  Vishwesh Krishnamoorthy
# ..                          ...                      ...
# 66                           83               Kabir Khan
# 67                   Atrangi Re            Aanand L. Rai
# 68  Murder at Teesri Manzil 302        Navneet Baj Saini
# 69                 Waah Zindagi           Dinesh S Yadav
# 70                          NaN                      NaN
#
#                                                  Cast       actor_1_name  \
# 0   [Mohit Chadda, Pavan Malhotra, Zakir Hussain, ...       Mohit Chadda
# 1                        [Kunal Kapoor, Amyra Dastur]       Kunal Kapoor
# 2   [Abhishek Bachchan, Ileana D'Cruz, Sohum Shah,...  Abhishek Bachchan
# 3   [Aadar Jain, Jackie Shroff, Elnaaz Norouzi, Sh...         Aadar Jain
# 4   [Ehan Bhat, Edilsy Vargas, Tenzin Dalha, Adity...          Ehan Bhat
# ..                                                ...                ...
# 66  [Ranveer Singh, Deepika Padukone, Tahir Raj Bh...      Ranveer Singh
# 67             [Dhanush, Sara Ali Khan, Akshay Kumar]            Dhanush
# 68  [Irrfan Khan, Ranvir Shorey, Deepal Shaw, Luck...        Irrfan Khan
# 69  [Naveen Kasturia, Plabita Borthakur, Vijay Raa...    Naveen Kasturia
# 70                                                 []                NaN
#
#          actor_2_name      actor_3_name
# 0      Pavan Malhotra     Zakir Hussain
# 1        Amyra Dastur               NaN
# 2       Ileana D'Cruz        Sohum Shah
# 3       Jackie Shroff    Elnaaz Norouzi
# 4       Edilsy Vargas      Tenzin Dalha
# ..                ...               ...
# 66   Deepika Padukone  Tahir Raj Bhasin
# 67      Sara Ali Khan      Akshay Kumar
# 68      Ranvir Shorey       Deepal Shaw
# 69  Plabita Borthakur        Vijay Raaz
# 70                NaN               NaN
#
# [71 rows x 6 columns]

# %%
data_2021_movies.drop('Cast',axis=1,inplace=True)

# %%
data_2021_movies['Title'] = data_2021_movies['Title'].str.lower()

# %%
data_2021_movies
# Out:
#                           Title                 Director       actor_1_name  \
# 0                        flight              Suraj Joshi       Mohit Chadda
# 1                  koi jaane na               Amin Hajee       Kunal Kapoor
# 2                  the big bull            Kookie Gulati  Abhishek Bachchan
# 3                 hello charlie          Pankaj Saraswat         Aadar Jain
# 4                   99 songs[b]  Vishwesh Krishnamoorthy          Ehan Bhat
# ..                          ...                      ...                ...
# 66                           83               Kabir Khan      Ranveer Singh
# 67                   atrangi re            Aanand L. Rai            Dhanush
# 68  murder at teesri manzil 302        Navneet Baj Saini        Irrfan Khan
# 69                 waah zindagi           Dinesh S Yadav    Naveen Kasturia
# 70                          NaN                      NaN                NaN
#
#          actor_2_name      actor_3_name
# 0      Pavan Malhotra     Zakir Hussain
# 1        Amyra Dastur               NaN
# 2       Ileana D'Cruz        Sohum Shah
# 3       Jackie Shroff    Elnaaz Norouzi
# 4       Edilsy Vargas      Tenzin Dalha
# ..                ...               ...
# 66   Deepika Padukone  Tahir Raj Bhasin
# 67      Sara Ali Khan      Akshay Kumar
# 68      Ranvir Shorey       Deepal Shaw
# 69  Plabita Borthakur        Vijay Raaz
# 70                NaN               NaN
#
# [71 rows x 5 columns]

# %%
data_2021_movies['genres'] = data_2021_movies['Title'].apply(lambda x:get_genres(x))
# Out:
# Error fetching genres for 99 songs[b]: attribute name must be string, not 'int'
# Error fetching genres for thalaivii[c]: attribute name must be string, not 'int'
# Error fetching genres for haathi mere saathi[d]: attribute name must be string, not 'int'
# Error fetching genres for nan: quote_from_bytes() expected bytes

# %%
data_2021_movies
# Out:
#                           Title                 Director       actor_1_name  \
# 0                        flight              Suraj Joshi       Mohit Chadda
# 1                  koi jaane na               Amin Hajee       Kunal Kapoor
# 2                  the big bull            Kookie Gulati  Abhishek Bachchan
# 3                 hello charlie          Pankaj Saraswat         Aadar Jain
# 4                   99 songs[b]  Vishwesh Krishnamoorthy          Ehan Bhat
# ..                          ...                      ...                ...
# 66                           83               Kabir Khan      Ranveer Singh
# 67                   atrangi re            Aanand L. Rai            Dhanush
# 68  murder at teesri manzil 302        Navneet Baj Saini        Irrfan Khan
# 69                 waah zindagi           Dinesh S Yadav    Naveen Kasturia
# 70                          NaN                      NaN                NaN
#
#          actor_2_name      actor_3_name                genres
# 0      Pavan Malhotra     Zakir Hussain                 Drama
# 1        Amyra Dastur               NaN      Thriller Mystery
# 2       Ileana D'Cruz        Sohum Shah           Crime Drama
# 3       Jackie Shroff    Elnaaz Norouzi      Adventure Comedy
# 4       Edilsy Vargas      Tenzin Dalha                   NaN
# ..                ...               ...                   ...
# 66   Deepika Padukone  Tahir Raj Bhasin         Drama History
# 67      Sara Ali Khan      Akshay Kumar  Comedy Drama Romance
# 68      Ranvir Shorey       Deepal Shaw        Thriller Drama
# 69  Plabita Borthakur        Vijay Raaz  Comedy Drama Romance
# 70                NaN               NaN                   NaN
#
# [71 rows x 6 columns]

# %%
data_2021_movies = data_2021_movies.rename(columns={'Title':'movie_title',"Director":"director_name"})

# %%
data_2021_movies
# Out:
#                     movie_title            director_name       actor_1_name  \
# 0                        flight              Suraj Joshi       Mohit Chadda
# 1                  koi jaane na               Amin Hajee       Kunal Kapoor
# 2                  the big bull            Kookie Gulati  Abhishek Bachchan
# 3                 hello charlie          Pankaj Saraswat         Aadar Jain
# 4                   99 songs[b]  Vishwesh Krishnamoorthy          Ehan Bhat
# ..                          ...                      ...                ...
# 66                           83               Kabir Khan      Ranveer Singh
# 67                   atrangi re            Aanand L. Rai            Dhanush
# 68  murder at teesri manzil 302        Navneet Baj Saini        Irrfan Khan
# 69                 waah zindagi           Dinesh S Yadav    Naveen Kasturia
# 70                          NaN                      NaN                NaN
#
#          actor_2_name      actor_3_name                genres
# 0      Pavan Malhotra     Zakir Hussain                 Drama
# 1        Amyra Dastur               NaN      Thriller Mystery
# 2       Ileana D'Cruz        Sohum Shah           Crime Drama
# 3       Jackie Shroff    Elnaaz Norouzi      Adventure Comedy
# 4       Edilsy Vargas      Tenzin Dalha                   NaN
# ..                ...               ...                   ...
# 66   Deepika Padukone  Tahir Raj Bhasin         Drama History
# 67      Sara Ali Khan      Akshay Kumar  Comedy Drama Romance
# 68      Ranvir Shorey       Deepal Shaw        Thriller Drama
# 69  Plabita Borthakur        Vijay Raaz  Comedy Drama Romance
# 70                NaN               NaN                   NaN
#
# [71 rows x 6 columns]

# %%
data_2021_movies.drop_duplicates(subset="movie_title",inplace=True)

# %%
data_2021_movies.isnull().sum()
# Out:
# movie_title       1
# director_name     1
# actor_1_name      1
# actor_2_name      3
# actor_3_name     16
# genres           13
# dtype: int64

# %%
data_2021_movies.dropna(inplace=True)

# %%
data_2021_movies.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
len(data_2021_movies)
# Out:
# 46

# %%
data_2021_movies
# Out:
#                          movie_title  \
# 0                             flight
# 2                       the big bull
# 3                      hello charlie
# 6                    ajeeb daastaans
# 7                 bansuri: the flute
# 8                     raat baaki hai
# 12                             radhe
# 13                sardar ka grandson
# 14                       shaadisthan
# 15                       skater girl
# 17                   haseen dillruba
# 18                       collar bomb
# 19     state of siege: temple attack
# 20                           toofaan
# 22                         hungama 2
# 23                              mimi
# 24                          dial 100
# 26                         shershaah
# 27          bhuj: the pride of india
# 28                       bell bottom
# 29                    200 – halla ho
# 30                            chehre
# 32                          faactory
# 33                      bhoot police
# 34  kya meri sonam gupta bewafa hai?
# 37                   ankahi kahaniya
# 39                           shiddat
# 41                     rashmi rocket
# 42                             sanak
# 45                   babloo bachelor
# 46                      aafat-e-ishq
# 47                           bekhudi
# 48                            dybbuk
# 49                  hum do hamare do
# 51                      sooryavanshi
# 52                             squad
# 53                 bunty aur babli 2
# 55                              cash
# 56                   ye mard bechara
# 58            antim: the final truth
# 63                             velle
# 65                           420 ipc
# 66                                83
# 67                        atrangi re
# 68       murder at teesri manzil 302
# 69                      waah zindagi
#
#                                         director_name           actor_1_name  \
# 0                                         Suraj Joshi           Mohit Chadda
# 2                                       Kookie Gulati      Abhishek Bachchan
# 3                                     Pankaj Saraswat             Aadar Jain
# 6   Shashank KhaitanRaj MehtaNeeraj GhaywanKayoze ...     Fatima Sana Shaikh
# 7                                      Hari Viswanath         Anurag Kashyap
# 8                                         Avinash Das              Paoli Dam
# 12                                        Prabhu Deva            Salman Khan
# 13                                      Kaashvie Nair           Arjun Kapoor
# 14                                Raj Singh Chaudhary          Kirti Kulhari
# 15                                   Manjari Makijany  Rachel Sanchita Gupta
# 17                                       Vinil Mathew          Taapsee Pannu
# 18                                    Dnyanesh Zoting        Jimmy Sheirgill
# 19                                          Ken Ghosh         Akshaye Khanna
# 20                            Rakeysh Omprakash Mehra          Farhan Akhtar
# 22                                       Priyadarshan           Paresh Rawal
# 23                                      Laxman Utekar            Kriti Sanon
# 24                                     Rensil D'Silva         Manoj Bajpayee
# 26                                      Vishnuvardhan      Sidharth Malhotra
# 27                                  Abhishek Dudhaiya             Ajay Devgn
# 28                                    Ranjit M Tewari           Akshay Kumar
# 29                                   Sarthak Dasgupta           Amol Palekar
# 30                                         Rumi Jafry       Amitabh Bachchan
# 32                                        Faisal Khan            Faisal Khan
# 33                                    Pavan Kirpalani          Saif Ali Khan
# 34                                     Ssaurabh Tyagi            Jassie Gill
# 37  Ashwiny Iyer TiwariAbhishek ChaubeySaket Chaud...      Abhishek Banerjee
# 39                                     Kunal Deshmukh          Sunny Kaushal
# 41                                     Akarsh Khurana          Taapsee Pannu
# 42                                      Kanishk Varma         Vidyut Jammwal
# 45                                 Agnidev Chatterjee          Sharman Joshi
# 46                                   Indrajit Nattoji            Neha Sharma
# 47                                       Amit Kasaria         Adhyayan Suman
# 48                                              Jay K          Emraan Hashmi
# 49                                      Abhishek Jain          Rajkummar Rao
# 51                                       Rohit Shetty           Akshay Kumar
# 52                                       Nilesh Sahay      Rinzing Denzongpa
# 53                                    Varun V. Sharma          Saif Ali Khan
# 55                                        Rishab Seth          Amol Parashar
# 56                                        Anuup Thapa             Veeraj Rao
# 58                                   Mahesh Manjrekar            Salman Khan
# 63                                       Deven Munjal             Karan Deol
# 65                                       Manish Gupta           Vinay Pathak
# 66                                         Kabir Khan          Ranveer Singh
# 67                                      Aanand L. Rai                Dhanush
# 68                                  Navneet Baj Saini            Irrfan Khan
# 69                                     Dinesh S Yadav        Naveen Kasturia
#
#           actor_2_name           actor_3_name  \
# 0       Pavan Malhotra          Zakir Hussain
# 2        Ileana D'Cruz             Sohum Shah
# 3        Jackie Shroff         Elnaaz Norouzi
# 6      Jaideep Ahlawat    Nushrratt Bharuccha
# 7   Rituparna Sengupta         Upendra Limaye
# 8            Anup Soni              Rahul Dev
# 12        Disha Patani          Jackie Shroff
# 13   Rakul Preet Singh            Neena Gupta
# 14       Medha Shankar  Nivedita Bhattacharya
# 15    Shraddha Gaikwad          Amrit Maghera
# 17      Vikrant Massey      Harshvardhan Rane
# 18           Asha Negi      Rajshri Deshpande
# 19     Abhimanyu Singh            Gautam Rode
# 20        Paresh Rawal          Mrunal Thakur
# 22       Shilpa Shetty          Meezaan Jafri
# 23     Pankaj Tripathi          Sai Tamhankar
# 24         Neena Gupta          Sakshi Tanwar
# 26        Kiara Advani           Shiv Panditt
# 27         Sanjay Dutt          Sharad Kelkar
# 28        Vaani Kapoor           Huma Qureshi
# 29         Barun Sobti          Rinku Rajguru
# 30       Emraan Hashmi        Krystle D'Souza
# 32        Roaleey Ryan       Rajkumar Kanojia
# 33        Arjun Kapoor   Jacqueline Fernandez
# 34        Surbhi Jyoti          Surekha Sikri
# 37       Rinku Rajguru          Delzad Hiwale
# 39       Radhika Madan            Mohit Raina
# 41  Priyanshu Painyuli      Abhishek Banerjee
# 42      Rukmini Maitra            Neha Dhupia
# 45        Pooja Chopra       Tejashri Pradhan
# 46     Deepak Dobriyal              Namit Das
# 47               Angel            Gulki Joshi
# 48        Nikita Dutta             Manav Kaul
# 49         Kriti Sanon           Paresh Rawal
# 51        Katrina Kaif             Ajay Devgn
# 52        Malvika Raaj            Pooja Batra
# 53        Rani Mukerji    Siddhant Chaturvedi
# 55       Smiriti Kalra        Swanand Kirkire
# 56     Manukriti Pahwa            Seema Pahwa
# 58       Aayush Sharma         Mahima Makwana
# 63          Abhay Deol              Mouni Roy
# 65       Ranvir Shorey              Gul Panag
# 66    Deepika Padukone       Tahir Raj Bhasin
# 67       Sara Ali Khan           Akshay Kumar
# 68       Ranvir Shorey            Deepal Shaw
# 69   Plabita Borthakur             Vijay Raaz
#
#                                  genres
# 0                                 Drama
# 2                           Crime Drama
# 3                      Adventure Comedy
# 6                         Drama Romance
# 7                                 Drama
# 8                  Crime Thriller Drama
# 12                               Action
# 13          Comedy Drama Romance Family
# 14                Adventure Drama Music
# 15                         Drama Family
# 17       Mystery Crime Thriller Romance
# 18                       Crime Thriller
# 19                         Action Drama
# 20                          Documentary
# 22                               Comedy
# 23                        Drama Romance
# 24                     Mystery Thriller
# 26            Action Drama Thriller War
# 27             War History Action Drama
# 28                      Thriller Action
# 29                       Crime Thriller
# 30               Thriller Mystery Drama
# 32  Action Crime Drama Romance Thriller
# 33              Adventure Horror Comedy
# 34                         Comedy Drama
# 37                        Drama Romance
# 39                        Romance Drama
# 41                                Drama
# 42                      Action Thriller
# 45                         Drama Comedy
# 46                Comedy Drama Thriller
# 47                   Action Crime Drama
# 48                Horror Thriller Drama
# 49                  Comedy Drama Family
# 51                Action Crime Thriller
# 52                               Action
# 53                   Comedy Crime Drama
# 55                               Comedy
# 56                               Comedy
# 58                               Action
# 63                         Comedy Crime
# 65                          Crime Drama
# 66                        Drama History
# 67                 Comedy Drama Romance
# 68                       Thriller Drama
# 69                 Comedy Drama Romance

# %%
data_2021_movies.to_csv('data_2021_movies.csv',index=False)

# %%
d1,d2,d3,d4 = create_df('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2022')

data_2022_movies = pd.concat([d1,d2,d3,d4]).reset_index()

data_2022_movies = data_2022_movies[['Title','Director','Cast']]

data_2022_movies['Cast'] = data_2022_movies['Cast'].fillna('')

import re

# Apply the split function
data_2022_movies['Cast'] = data_2022_movies['Cast'].apply(
    lambda x: re.split(r'(?<=[a-z])(?=[A-Z])', x)
)
data_2022_movies['actor_1_name'] = data_2022_movies['Cast'].apply(lambda x:get_actor1(x))
data_2022_movies['actor_2_name'] = data_2022_movies['Cast'].apply(lambda x:get_actor2(x))
data_2022_movies['actor_3_name'] = data_2022_movies['Cast'].apply(lambda x:get_actor3(x))

data_2022_movies.drop('Cast',axis=1,inplace=True)

data_2022_movies['Title'] = data_2022_movies['Title'].str.lower()

data_2022_movies['genres'] = data_2022_movies['Title'].apply(lambda x:get_genres(x))

data_2022_movies = data_2022_movies.rename(columns={'Title':'movie_title',"Director":"director_name"})
# Out:
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for rocketry: the nambi effect[c]: attribute name must be string, not 'int'
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for dedh lakh ka dulha: attribute name must be string, not 'int'
# Error fetching genres for nan: quote_from_bytes() expected bytes

# %%
data_2022_movies
# Out:
#                 movie_title           director_name       actor_1_name  \
# 0              36 farmhouse        Ram Ramesh Sharm         Vijay Raaz
# 1    hai tujhe salaam india           Avanish Kumar       Aarya Babbar
# 2              looop lapeta           Aakash Bhatia      Taapsee Pannu
# 3                gehraiyaan            Shakun Batra   Deepika Padukone
# 4                badhaai do  Harshavardhan Kulkarni      Rajkummar Rao
# ..                      ...                     ...                ...
# 107            ajay wardhan         Pragati Agarwal     Ruslaan Mumtaz
# 108                trahimam   Dushyant Pratap Singh         Arshi Khan
# 109                  cirkus            Rohit Shetty      Ranveer Singh
# 110      dedh lakh ka dulha      Abhay Pratap Singh  Akhilendra Mishra
# 111                     NaN                     NaN                NaN
#
#             actor_2_name          actor_3_name                genres
# 0          Sanjay Mishra         Amol Parashar  Comedy Drama Mystery
# 1              Ajaz Khan         Smita Gondkar                   NaN
# 2       Tahir Raj Bhasin                   NaN   Action Comedy Crime
# 3    Siddhant Chaturvedi         Ananya Panday         Romance Drama
# 4         Bhumi Pednekar                   NaN          Comedy Drama
# ..                   ...                   ...                   ...
# 107      Arjumman Mughal                   NaN                   NaN
# 108         Pankaj Berry                   NaN                   NaN
# 109          Pooja Hegde  Jacqueline Fernandez                   NaN
# 110        Ishtiyak Khan       Harshita Panwar                   NaN
# 111                  NaN                   NaN                   NaN
#
# [112 rows x 6 columns]

# %%
data_2022_movies.dropna(inplace=True)

# %%
data_2022_movies
# Out:
#              movie_title          director_name        actor_1_name  \
# 0           36 farmhouse       Ram Ramesh Sharm          Vijay Raaz
# 3             gehraiyaan           Shakun Batra    Deepika Padukone
# 5             a thursday        Behzad Khambata         Yami Gautam
# 6    gangubai kathiawadi  Sanjay Leela Bhansali          Alia Bhatt
# 7            love hostel          Shanker Raman      Sanya Malhotra
# ..                   ...                    ...                 ...
# 95          mister mummy              Shaad Ali    Riteish Deshmukh
# 97                  qala            Anvita Dutt        Tripti Dimri
# 100       india lockdown      Madhur Bhandarkar  Shweta Basu Prasad
# 103             maarrich           Dhruv Lather      Tusshar Kapoor
# 106    govinda naam mera       Shashank Khaitan       Vicky Kaushal
#
#             actor_2_name         actor_3_name                  genres
# 0          Sanjay Mishra        Amol Parashar    Comedy Drama Mystery
# 3    Siddhant Chaturvedi        Ananya Panday           Romance Drama
# 5            Neha Dhupia        Atul Kulkarni             Crime Drama
# 6             Ajay Devgn  Shantanu Maheshwari     Crime Drama History
# 7         Vikrant Massey           Bobby Deol  Crime Romance Thriller
# ..                   ...                  ...                     ...
# 95      Genelia Deshmukh     Mahesh Manjrekar            Comedy Drama
# 97    Swastika Mukherjee           Babil Khan                   Drama
# 100         Aahana Kumra       Prateik Babbar         Drama Adventure
# 103     Naseeruddin Shah            Rahul Dev          Thriller Crime
# 106         Kiara Advani       Bhumi Pednekar    Comedy Drama Romance
#
# [71 rows x 6 columns]

# %%
data_2022_movies.drop_duplicates(subset='movie_title')
# Out:
#              movie_title          director_name        actor_1_name  \
# 0           36 farmhouse       Ram Ramesh Sharm          Vijay Raaz
# 3             gehraiyaan           Shakun Batra    Deepika Padukone
# 5             a thursday        Behzad Khambata         Yami Gautam
# 6    gangubai kathiawadi  Sanjay Leela Bhansali          Alia Bhatt
# 7            love hostel          Shanker Raman      Sanya Malhotra
# ..                   ...                    ...                 ...
# 95          mister mummy              Shaad Ali    Riteish Deshmukh
# 97                  qala            Anvita Dutt        Tripti Dimri
# 100       india lockdown      Madhur Bhandarkar  Shweta Basu Prasad
# 103             maarrich           Dhruv Lather      Tusshar Kapoor
# 106    govinda naam mera       Shashank Khaitan       Vicky Kaushal
#
#             actor_2_name         actor_3_name                  genres
# 0          Sanjay Mishra        Amol Parashar    Comedy Drama Mystery
# 3    Siddhant Chaturvedi        Ananya Panday           Romance Drama
# 5            Neha Dhupia        Atul Kulkarni             Crime Drama
# 6             Ajay Devgn  Shantanu Maheshwari     Crime Drama History
# 7         Vikrant Massey           Bobby Deol  Crime Romance Thriller
# ..                   ...                  ...                     ...
# 95      Genelia Deshmukh     Mahesh Manjrekar            Comedy Drama
# 97    Swastika Mukherjee           Babil Khan                   Drama
# 100         Aahana Kumra       Prateik Babbar         Drama Adventure
# 103     Naseeruddin Shah            Rahul Dev          Thriller Crime
# 106         Kiara Advani       Bhumi Pednekar    Comedy Drama Romance
#
# [71 rows x 6 columns]

# %%
data_2022_movies
# Out:
#              movie_title          director_name        actor_1_name  \
# 0           36 farmhouse       Ram Ramesh Sharm          Vijay Raaz
# 3             gehraiyaan           Shakun Batra    Deepika Padukone
# 5             a thursday        Behzad Khambata         Yami Gautam
# 6    gangubai kathiawadi  Sanjay Leela Bhansali          Alia Bhatt
# 7            love hostel          Shanker Raman      Sanya Malhotra
# ..                   ...                    ...                 ...
# 95          mister mummy              Shaad Ali    Riteish Deshmukh
# 97                  qala            Anvita Dutt        Tripti Dimri
# 100       india lockdown      Madhur Bhandarkar  Shweta Basu Prasad
# 103             maarrich           Dhruv Lather      Tusshar Kapoor
# 106    govinda naam mera       Shashank Khaitan       Vicky Kaushal
#
#             actor_2_name         actor_3_name                  genres
# 0          Sanjay Mishra        Amol Parashar    Comedy Drama Mystery
# 3    Siddhant Chaturvedi        Ananya Panday           Romance Drama
# 5            Neha Dhupia        Atul Kulkarni             Crime Drama
# 6             Ajay Devgn  Shantanu Maheshwari     Crime Drama History
# 7         Vikrant Massey           Bobby Deol  Crime Romance Thriller
# ..                   ...                  ...                     ...
# 95      Genelia Deshmukh     Mahesh Manjrekar            Comedy Drama
# 97    Swastika Mukherjee           Babil Khan                   Drama
# 100         Aahana Kumra       Prateik Babbar         Drama Adventure
# 103     Naseeruddin Shah            Rahul Dev          Thriller Crime
# 106         Kiara Advani       Bhumi Pednekar    Comedy Drama Romance
#
# [71 rows x 6 columns]

# %%
data_2022_movies.to_csv('data_2022_movies.csv',index=False)

# %%
d1,d2,d3,d4 = create_df('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2023')

data_2023_movies = pd.concat([d1,d2,d3,d4]).reset_index()

data_2023_movies = data_2023_movies[['Title','Director','Cast']]

data_2023_movies['Cast'] = data_2023_movies['Cast'].fillna('')

import re

# Apply the split function
data_2023_movies['Cast'] = data_2023_movies['Cast'].apply(
    lambda x: re.split(r'(?<=[a-z])(?=[A-Z])', x)
)
data_2023_movies['actor_1_name'] = data_2023_movies['Cast'].apply(lambda x:get_actor1(x))
data_2023_movies['actor_2_name'] = data_2023_movies['Cast'].apply(lambda x:get_actor2(x))
data_2023_movies['actor_3_name'] = data_2023_movies['Cast'].apply(lambda x:get_actor3(x))

data_2023_movies.drop('Cast',axis=1,inplace=True)

data_2023_movies['Title'] = data_2023_movies['Title'].str.lower()

data_2023_movies['genres'] = data_2023_movies['Title'].apply(lambda x:get_genres(x))

data_2023_movies = data_2023_movies.rename(columns={'Title':'movie_title',"Director":"director_name"})
# Out:
# Error fetching genres for operation fryday[b]: attribute name must be string, not 'int'
# Error fetching genres for the tenant[c]: attribute name must be string, not 'int'
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for mystery of the tattoo: attribute name must be string, not 'int'
# Error fetching genres for sab moh maaya hai: attribute name must be string, not 'int'

# %%
data_2023_movies
# Out:
#             movie_title                             director_name  \
# 0                kuttey                          Aasmaan Bhardwaj
# 1           lakadbaggha                          Victor Mukherjee
# 2         mission majnu                           Shantanu Bagchi
# 3           chhatriwali                             Tejas Deoskar
# 4               pathaan                           Siddharth Anand
# ..                  ...                                       ...
# 131        kaisi ye dor  Ratna Neelam Pandey Sandeep S. Choudhary
# 132               dunki                           Rajkumar Hirani
# 133             dry day                            Saurabh Shukla
# 134  kho gaye hum kahan                        Arjun Varain Singh
# 135               safed                             Sandeep Singh
#
#           actor_1_name         actor_2_name         actor_3_name  \
# 0         Arjun Kapoor                 Tabu   Konkona Sen Sharma
# 1         Anshuman Jha         Riddhi Dogra         Milind Soman
# 2    Sidharth Malhotra    Rashmika Mandanna         Kumud Mishra
# 3    Rakul Preet Singh          Sumeet Vyas       Satish Kaushik
# 4       Shah Rukh Khan         John Abraham     Deepika Padukone
# ..                 ...                  ...                  ...
# 131      Nikhil Pandey      Jashn Agnihotri  Ratna Neelam Pandey
# 132     Shah Rukh Khan        Taapsee Pannu        Vicky Kaushal
# 133     Jitendra Kumar          Annu Kapoor    Shriya Pilgaonkar
# 134      Adarsh Gourav  Siddhant Chaturvedi        Ananya Panday
# 135        Abhay Verma         Meera Chopra                  NaN
#
#                               genres
# 0              Comedy Crime Thriller
# 1              Action Crime Thriller
# 2      Thriller Action Drama History
# 3                       Comedy Drama
# 4    Action Adventure Thriller Drama
# ..                               ...
# 131                     Drama Family
# 132                 War Action Drama
# 133                     Comedy Drama
# 134                     Drama Comedy
# 135                            Drama
#
# [136 rows x 6 columns]

# %%
data_2023_movies.duplicated().sum()
# Out:
# 0

# %%
data_2023_movies.isnull().sum()
# Out:
# movie_title       1
# director_name     1
# actor_1_name      1
# actor_2_name      5
# actor_3_name     22
# genres           14
# dtype: int64

# %%
data_2023_movies.dropna(inplace=True)

# %%
len(data_2023_movies)
# Out:
# 104

# %%
data_2023_movies.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data_2023_movies.to_csv("data_2023_movies.csv",index=False)

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from requests.exceptions import Timeout, RequestException, ConnectionError
import numpy as np
from functools import lru_cache
from tmdbv3api import TMDb, Movie
from concurrent.futures import ThreadPoolExecutor, as_completed

tmdb = TMDb()
tmdb.api_key = '6d8bfe0dbef34d25e64f64cabec93e20'
tmdb_movie = Movie()

# Using LRU cache to store results of previously fetched movie genres
@lru_cache(maxsize=1000)
def fetch_movie_genres(movie_id):
    try:
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
        if response.status_code != 200:
            return np.nan
        
        data_json = response.json()
        if 'genres' in data_json and data_json['genres']:
            return " ".join([genre['name'] for genre in data_json['genres']])
        else:
            return np.nan
    except Exception as e:
        print(f"Error fetching genres for movie ID {movie_id}: {e}")
        return np.nan

def get_genres(x):
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.nan
        
        movie_id = result[0].id
        return fetch_movie_genres(movie_id)
    except Exception as e:
        print(f"Error fetching genres for {x}: {e}")
        return np.nan

# Setup retry strategy
retry_strategy = Retry(
    total=5,  # Total number of retries
    backoff_factor=2,  # Exponential backoff factor
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    method_whitelist=["HEAD", "GET", "OPTIONS"]  # Retry only on these methods
)

# Create an HTTP adapter with the retry strategy
adapter = HTTPAdapter(max_retries=retry_strategy)

# Create a session and mount the adapter
session = requests.Session()
session.mount("https://", adapter)
session.mount("http://", adapter)

def get(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if actor_list[0]:
            return actor_list[0].strip()
    return None

def get2(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if len(actor_list) >= 2:
            return actor_list[1].strip()
        else:
            return np.nan
    return np.nan

def get3(x):
    if isinstance(x, str):
        actor_list = x.split(",")
        if len(actor_list) >= 3:
            return actor_list[2].strip()
        else:
            return np.nan
    return np.nan

def fetch_html(url):
    try:
        response = session.get(url, timeout=20)
        response.raise_for_status()  # Raise an exception for HTTP errors
        return response.content
    except Timeout:
        print(f"Request timed out for URL {url}.")
        return None
    except ConnectionError as e:
        print(f"Connection error for URL {url}: {e}")
        return None
    except RequestException as e:
        print(f"Request error fetching data from URL {url}: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error fetching data from URL {url}: {e}")
        return None

def create_df(url):
    # Fetch HTML content from the URL
    html_content = fetch_html(url)

    # Read HTML data using pandas if content is fetched successfully
    if html_content:
        try:
            # Reading multiple tables on the page
            tables = pd.read_html(html_content, header=0)
        
            # Extract specific tables

            df1 = tables[4]
            df2 = tables[5]
            df3 = tables[6]
            df4 = tables[7]
        
        except Exception as e:
            print(f"Error reading HTML content: {e}")
    else:
        print("Failed to fetch HTML content.")
    
    return df1,df2,df3,df4
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_6844\895847421.py:45: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(

# %%
d1,d2,d3,d4 = create_df('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_2024')

data_2024_movies = pd.concat([d1,d2,d3,d4]).reset_index()

data_2024_movies = data_2024_movies[['Title','Director','Cast']]

data_2024_movies['Cast'] = data_2024_movies['Cast'].fillna('')

import re

# Apply the split function
data_2024_movies['Cast'] = data_2024_movies['Cast'].apply(
    lambda x: re.split(r'(?<=[a-z])(?=[A-Z])', x)
)
data_2024_movies['actor_1_name'] = data_2024_movies['Cast'].apply(lambda x:get_actor1(x))
data_2024_movies['actor_2_name'] = data_2024_movies['Cast'].apply(lambda x:get_actor2(x))
data_2024_movies['actor_3_name'] = data_2024_movies['Cast'].apply(lambda x:get_actor3(x))

data_2024_movies.drop('Cast',axis=1,inplace=True)

data_2024_movies['Title'] = data_2024_movies['Title'].str.lower()

data_2024_movies['genres'] = data_2024_movies['Title'].apply(lambda x:get_genres(x))

data_2024_movies = data_2024_movies.rename(columns={'Title':'movie_title',"Director":"director_name"})
# Out:
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for operation valentine[b]: attribute name must be string, not 'int'
# Error fetching genres for swatantrya veer savarkar: attribute name must be string, not 'int'
# Error fetching genres for nan: quote_from_bytes() expected bytes
# Error fetching genres for the legacy of jineshwar: attribute name must be string, not 'int'
# Error fetching genres for tipppsy: attribute name must be string, not 'int'
# Error fetching genres for hamare baarah: attribute name must be string, not 'int'
# Error fetching genres for kalki 2898 ad[b]: attribute name must be string, not 'int'
# Error fetching genres for chhaava: attribute name must be string, not 'int'

# %%
data_2024_movies
# Out:
#               movie_title     director_name      actor_1_name  \
# 0        tauba tera jalwa  Akashaditya Lama     Jatin Khurana
# 1      merry christmas[a]   Sriram Raghavan      Katrina Kaif
# 2          main atal hoon       Ravi Jadhav   Pankaj Tripathi
# 3                 fighter   Siddharth Anand    Hrithik Roshan
# 4                     NaN               NaN               NaN
# ..                    ...               ...               ...
# 76                 raid 2   Raj Kumar Gupta        Ajay Devgn
# 77       metro... in dino       Anurag Basu  Aditya Roy Kapur
# 78                chhaava     Laxman Utekar     Vicky Kaushal
# 79  welcome to the jungle        Ahmed Khan      Akshay Kumar
# 80     sitaare zameen par     R.S. Prasanna        Aamir Khan
#
#          actor_2_name       actor_3_name                 genres
# 0       Ameesha Patel  Angela Krislinzki       Romance Thriller
# 1    Vijay Sethupathi                NaN          Comedy Family
# 2                 NaN                NaN                  Drama
# 3    Deepika Padukone        Anil Kapoor    Action Thriller War
# 4                 NaN                NaN                    NaN
# ..                ...                ...                    ...
# 76   Riteish Deshmukh       Vaani Kapoor  Action Crime Thriller
# 77      Sara Ali Khan        Anupam Kher          Drama Romance
# 78  Rashmika Mandanna                NaN                    NaN
# 79        Sanjay Dutt      Suniel Shetty                 Comedy
# 80    Genelia D'Souza    Darsheel Safary           Comedy Drama
#
# [81 rows x 6 columns]

# %%
data_2024_movies.duplicated().sum()
# Out:
# 1

# %%
data_2024_movies.drop_duplicates(inplace=True)

# %%
data_2024_movies.isnull().sum()
# Out:
# movie_title       1
# director_name     1
# actor_1_name      1
# actor_2_name      4
# actor_3_name     14
# genres           17
# dtype: int64

# %%
len(data_2024_movies)
# Out:
# 80

# %%
data_2024_movies.dropna(inplace=True)

# %%
data_2024_movies.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
len(data_2024_movies)
# Out:
# 53

# %%
data_2024_movies.to_csv("data_2024_movies.csv",index=False)

# %%
data1 = pd.read_csv('D:\Movies\movies_upto_2017.csv')
data2 = pd.read_csv('D:\Movies\data_2018_movies.csv')
data3 = pd.read_csv('D:\Movies\data_2019_movies.csv')
data4 = pd.read_csv('D:\Movies\data_2020_movies.csv')
data5 = pd.read_csv('D:\Movies\data_2021_movies.csv')
data6 = pd.read_csv('D:\Movies\data_2022_movies.csv')
data7 = pd.read_csv("D:\Movies\data_2023_movies.csv")
data8 = pd.read_csv("D:\Movies\data_2024_movies.csv")

# %%
print(len(data1)+len(data2)+len(data3)+len(data4)+len(data5)+len(data6)+len(data7)+len(data8))
# Out:
# 5745

# %%
data1.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# comb             0
# dtype: int64

# %%
data3.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data4.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data5.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data6.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data7.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data8.isnull().sum()
# Out:
# movie_title      0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# dtype: int64

# %%
data1.head(1)
# Out:
#    director_name actor_1_name      actor_2_name actor_3_name  \
# 0  James Cameron  CCH Pounder  Joel David Moore    Wes Studi
#
#                             genres movie_title  \
# 0  Action Adventure Fantasy Sci-Fi      avatar
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...

# %%
data2.head(1)
# Out:
#   movie_title director_name actor_1_name  actor_2_name   actor_3_name  \
# 0        1921  Vikram Bhatt  Zareen Khan  Karan Kundra  Tobby Hinston
#
#               genres                                               comb
# 0  History Drama War  Zareen Khan Karan Kundra Tobby Hinston Vikram ...

# %%
data3['comb'] = data3['actor_1_name']+" "+data3['actor_2_name']+" "+data3['actor_3_name']+" "+data3['director_name']
data4['comb'] = data4['actor_1_name']+" "+data4['actor_2_name']+" "+data4['actor_3_name']+" "+data4['director_name']
data5['comb'] = data5['actor_1_name']+" "+data5['actor_2_name']+" "+data5['actor_3_name']+" "+data5['director_name']
data6['comb'] = data6['actor_1_name']+" "+data6['actor_2_name']+" "+data6['actor_3_name']+" "+data6['director_name']
data7['comb'] = data7['actor_1_name']+" "+data7['actor_2_name']+" "+data7['actor_3_name']+" "+data7['director_name']
data8['comb'] = data8['actor_1_name']+" "+data8['actor_2_name']+" "+data8['actor_3_name']+" "+data8['director_name']

# %%
data3.head(1)
# Out:
#    movie_title    director_name       actor_1_name              actor_2_name  \
# 0  salt bridge  Abhijit Deonath  Rajeev Khandelwal  Chelsie Preston Crayford
#
#   actor_3_name genres                                               comb
# 0  Usha Jadhav  Drama  Rajeev Khandelwal Chelsie Preston Crayford Ush...

# %%
data4.head(1)
# Out:
#   movie_title   director_name  actor_1_name    actor_2_name actor_3_name  \
# 0     bamfaad  Ranjan Chandel  Aditya Rawal  Shalini Pandey  Vijay Varma
#
#           genres                                               comb
# 0  Romance Drama  Aditya Rawal Shalini Pandey Vijay Varma Ranjan...

# %%
data5.head(1)
# Out:
#   movie_title director_name  actor_1_name    actor_2_name   actor_3_name  \
# 0      flight   Suraj Joshi  Mohit Chadda  Pavan Malhotra  Zakir Hussain
#
#   genres                                               comb
# 0  Drama  Mohit Chadda Pavan Malhotra Zakir Hussain Sura...

# %%
data6.head(1)
# Out:
#     movie_title     director_name actor_1_name   actor_2_name   actor_3_name  \
# 0  36 farmhouse  Ram Ramesh Sharm   Vijay Raaz  Sanjay Mishra  Amol Parashar
#
#                  genres                                               comb
# 0  Comedy Drama Mystery  Vijay Raaz Sanjay Mishra Amol Parashar Ram Ram...

# %%
data7.head(1)
# Out:
#   movie_title     director_name  actor_1_name actor_2_name  \
# 0      kuttey  Aasmaan Bhardwaj  Arjun Kapoor         Tabu
#
#          actor_3_name                 genres  \
# 0  Konkona Sen Sharma  Comedy Crime Thriller
#
#                                                 comb
# 0  Arjun Kapoor Tabu Konkona Sen Sharma Aasmaan B...

# %%
data8.head(1)
# Out:
#         movie_title     director_name   actor_1_name   actor_2_name  \
# 0  tauba tera jalwa  Akashaditya Lama  Jatin Khurana  Ameesha Patel
#
#         actor_3_name            genres  \
# 0  Angela Krislinzki  Romance Thriller
#
#                                                 comb
# 0  Jatin Khurana Ameesha Patel Angela Krislinzki ...

# %%
final_movies_hindi_data = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8],axis=0)

# %%
final_movies_hindi_data.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
print(len(final_movies_hindi_data))
# Out:
# 5745

# %%
final_movies_hindi_data.to_csv('final_movies_hindi_data.csv',index=False)
